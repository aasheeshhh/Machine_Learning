# %%
import gymnasium as gym
import numpy as np
import random

# %%
env = gym.make("CliffWalking-v1")

# %%
print(env.observation_space) #states
print(env.action_space) #actions
print(env.reset()) # 36 starting state  3*12 + 0
# Out:
# Discrete(48)
# Discrete(4)
# (36, {'prob': 1})

# %%
# SARSA 
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500
